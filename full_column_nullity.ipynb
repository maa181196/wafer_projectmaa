# %%
def full_column_nullity(path):
    """here i am going to write a function for to check if in any file if all the column is null then,
    that file will be store in bad file"""
    lg.basicConfig(filename='ful_column_null.log',level=lg.INFO, format ='%(asctime)s %(message)s')
    lg.info("the exceution will be start from here",path)
    count =0
    try:
        for i in os.listdir("good_data1"):
            lg.info("we are entring into csv file")
            a=path+"\\"+"good_data1\\"+i
            df =pd.read_csv(a)
            columns =np.array(df.columns)
            for j in columns:
                if (len(df[j])-int(df[j].count()) ==len(df[j])):
                    shutil.move(a,path+"\\"+'bad_data1')
                    count+=1
                    lg.info("bad data transfer into bad_data1")
                    break
                    

                        
                else:
                    pass
        lg.info("total no. of file transfer",count)
    except Exception as e:
        print ("you can check in your log if your code will fail")
        lg.error("error has occured")
        lg.exception(str(e))

# %%
import os
import csv
import shutil
import logging as lg
import pandas as pd
import numpy as np
import mysql.connector as connection

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Desktop\\MACHINE_LEARNING_PROJECT'

# %%
path ='C:\\Users\\Admin\\Desktop\\MACHINE_LEARNING_PROJECT'
full_column_nullity(path)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 927, in format
#     return fmt.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
# ...
